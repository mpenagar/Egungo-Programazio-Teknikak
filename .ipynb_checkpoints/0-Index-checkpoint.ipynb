# %% [markdown]
# # Egungo Programazio Teknikak
#
# 1. [Datuen Zientzia eta Ikaskuntza Automatikorako Sarrera](1-Datuen_Zientzia_eta_Ikaskuntza_Automatikorako_Sarrera.ipynb)
# 1. E2E Machine Learning proiektua
# 1. Sailkapena
# 1. Ereduak
# 1. Datu-bilketa eta Datuen Analisi Esploratzailea
# 1. Multzokatzea
