# %% [markdown]
# # Numpy
#
# Ariketa multzo honek NumPy liburutegiaren oinarrizko eragiketak lantzen ditu, Machine Learning (ML) eremuan ohikoak diren datu-egitura, matrize-eragiketa eta aurreprozesamendu tekniketan ardatza jarriz.

# %% [markdown]
# ## 1. Bektore eta Matrizeen Sorrera

# %% [markdown]
# **Atalaseko bektorea:** Sortu 100 zeroz osatutako 1D array bat eta bihurtu $10 \times 10$ neurriko matrize bat.

# %% [markdown]
# **Pisu-matrizeen hasieratzea:** Sortu 1ez betetako $5 \times 3$ neurriko matrize bat.

# %% [markdown]
# **Sekuentzia lineala:** Sortu 10etik 50era bitarteko zenbaki bikoitien array bat (`np.arange` erabiliz).

# %% [markdown]
# **Espazio jarraitua:** Sortu 0 eta 1 artean berdinki banatutako 20 zenbakiz osatutako array bat (`np.linspace` erabiliz), optimizazio-atalaseak simulatzeko.

# %% [markdown]
# ## 2. Forma/Egitura Manipulazioa

# %% [markdown]
# **Dimensions & Transpose:** Sortu 12 elementuko 1D array bat, bihurtu $(4, 3)$ neurriko ezaugarri-matrize eta kalkulatu bere transposatua ($(3, 4)$ neurria lortuz).

# %% [markdown]
# 5. **Dimensions & Transpose:** Sortu 12 elementuko 1D array bat, bihurtu $(4, 3)$ neurriko ezaugarri-matrize eta kalkulatu bere transposatua ($(3, 4)$ neurria lortuz).
# 6. **Flattening / Unrolling:** Bihurtu $3 \times 3$ neurriko matrize bat 1D bektore linealean (`flatten` edo `ravel` erabiliz) —irudi baten pixelak ezaugarri-bektore bihurtzeko eragiketa klasikoa—.
#
# **3. Indizeak, Mozketak (Slicing) eta Maskara Boolearrak**
#
# 7. **Data-Split simulazioa ($X$ eta $y$):** $5 \times 4$ neurriko matrize bat izanda, banatu lehenengo 3 zutabeak ezaugarrien matrizean ($X$) eta azken zutabea helburu-bektorean ($y$).
# 8. **Azpi-multzoak erauztea:** Erauzi $4 \times 4$ matrize baten erdialdeko $2 \times 2$ azpimatrizea.
# 9. **Binarizazioa (Atalase-funtzioa):** Sortu 20 ausazko zenbakiko array bat (0 eta 1 artean). Maskara boolearra erabiliz, ordezkarazi 0.5 baino handiagoak diren balioak 1ekin eta txikiagoak 0rekin.
# 10. **ReLU Aktibazio-funtzioa:** Sortu balio positibo zein negatiboak dituen 1D bektore bat, eta ordezkarazi balio negatibo guztiak 0rekin (`np.maximum` edo maskara boolearra erabiliz).
#
# **4. Operazio Matematikoak eta Estatistika**
#
# 11. **Ardatzen arteko agregazioa:** $(5, 3)$ neurriko matrize baten batez bestekoa eta deboazio estandarra kalkulatu zutabe bakoitzeko (`axis=0`) eta errenkada bakoitzeko (`axis=1`).
# 12. **Min-Max Skalatzea (Normalization):** Normalizatu 1D array bat balio guztiak $[0, 1]$ tartean egon daitezen formula hau erabiliz:
#
# $$\frac{x - x_{min}}{x_{max} - x_{min}}$$
#
#
# 13. **Broadcasting bidezko estandarizazioa:** $(5, 3)$ matrize bati kendu zutabe bakoitzaren batez besteko bektorea (Broadcasting gaitasuna erabiliz ziurtatu eragiketa bektoriala dela).
# 14. **Sailkapen anitzeko iragarpena (Argmax):** $(5, 3)$ neurriko matrize batek 5 laginen 3 klase posibleen probabilitateak adierazten ditu. Aurkitu lagin bakoitzari dagokion klase iragarririkoaren indizea (`np.argmax` erabiliz `axis=1` ardatzean).
#
# **5. Aljebra Lineala eta Biderketak**
#
# 15. **Biderkadura eskalarra (Dot Product):** Kalkulatu ezaugarri-bektore baten ($x$, 4 luzerakoa) eta pisu-bektore baten ($w$, 4 luzerakoa) arteko biderkadura eskalarra ($w \cdot x$).
# 16. **Matrize-biderketa (Batch iragarpena):** Biderkatu $X$ datu-multzoa ($10 \times 4$ neurrikoa) eta $W$ pisu-matrizea ($4 \times 2$ neurrikoa) iragarpen-matrizea lortzeko (`@` eragilea edo `np.dot` erabiliz).
# 17. **Distantzia Euklidearra (k-NN oinarria):** Kalkulatu bi 1D bektoreren arteko distantzia euklidearra:
#
# $$d = \sqrt{\sum_{i=1}^{n} (a_i - b_i)^2}$$
#
#
#
# **6. Ausazko Zenbakiak eta Laginketa**
#
# 18. **Pisuen Ausazko Hasieratzea:** Erabili `np.random.seed(42)` birsortzea ziurtatzeko, eta sortu banaketa normal estandarra ($\mu=0, \sigma=1$) jarraitzen duen $(4, 3)$ neurriko pisu-matrize bat.
# 19. **Data Shuffling (Indizeak nahastea):** Sortu 0tik 99ra arteko indize-bektore bat eta nahastu ausaz (`np.random.shuffle`), datu-multzo bat entrenamendu/test multzoetan banatu aurretik nahasteko.
# 20. **Sigmoide Funtzio bektoriala:** Inplementatu NumPy erabiliz Sigmoide aktibazio-funtzioa eta aplikatu ausaz sortutako 1D bektore bati:
#
# $$\sigma(z) = \frac{1}{1 + e^{-z}}$$
